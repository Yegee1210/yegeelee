# %% [markdown]
# <a href="https://colab.research.google.com/github/Yegee1210/yegeelee/blob/master/%EB%82%98%EC%9D%98_%EC%8B%A4%EC%8A%B5_%EC%98%81%ED%99%94.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

# %%
import requests
url = "http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json?key=430156241533f1d058c603178cc3ca0e&targetDt=20120101"
res = requests.get(url)
text = res.text
MD_json = json.loads(text)

# %%
print(json.dumps(MD_json,indent=4,sort_keys=True))
# Out:
# {
#     "boxOfficeResult": {
#         "boxofficeType": "\uc77c\ubcc4 \ubc15\uc2a4\uc624\ud53c\uc2a4",
#         "dailyBoxOfficeList": [
#             {
#                 "audiAcc": "5328435",
#                 "audiChange": "-14.5",
#                 "audiCnt": "353274",
#                 "audiInten": "-60106",
#                 "movieCd": "20112207",
#                 "movieNm": "\ubbf8\uc158\uc784\ud30c\uc11c\ube14:\uace0\uc2a4\ud2b8\ud504\ub85c\ud1a0\ucf5c",
#                 "openDt": "2011-12-15",
#                 "rank": "1",
#                 "rankInten": "0",
#                 "rankOldAndNew": "OLD",
#                 "rnum": "1",
#                 "salesAcc": "40541108500",
#                 "salesAmt": "2776060500",
#                 "salesChange": "-13",
#                 "salesInten": "-415699000",
#                 "salesShare": "36.3",
#                 "scrnCnt": "697",
#                 "showCnt": "3223"
#             },
#             {
# ...

# %%
print(MD_json.keys())

print(MD_json['boxOfficeResult'].keys())
# Out:
# dict_keys(['boxOfficeResult'])
# dict_keys(['boxofficeType', 'showRange', 'dailyBoxOfficeList'])

# %%
for i in MD_json['boxOfficeResult']['dailyBoxOfficeList']:
  print(i['rank'],i['rankOldAndNew'],i['movieCd'],i['movieNm'],i['salesAmt'])
# Out:
# 1 OLD 20112207 미션임파서블:고스트프로토콜 2776060500
# 2 OLD 20110295 마이 웨이 1189058500
# 3 OLD 20112621 셜록홈즈 : 그림자 게임 1176022500
# 4 OLD 20113260 퍼펙트 게임 644532000
# 5 OLD 20113271 프렌즈: 몬스터섬의비밀  436753500
# 6 OLD 19940256 라이온 킹 507115500
# 7 OLD 20113381 오싹한 연애 344871000
# 8 OLD 20112709 극장판 포켓몬스터 베스트 위시「비크티니와 백의 영웅 레시라무」 167809500
# 9 OLD 20113311 앨빈과 슈퍼밴드3 137030000
# 10 OLD 20112708 극장판 포켓몬스터 베스트 위시 「비크티니와 흑의 영웅 제크로무」 125535500

# %%
import pandas as pd
movie = [] 
for i in MD_json['boxOfficeResult']['dailyBoxOfficeList']:
  movie.append([i['rank'],i['rankOldAndNew'],i['movieCd'],i['movieNm'],i['salesAmt']])
data = pd.DataFrame(movie)

# %%
data
# Out:
#     0    1         2                                    3           4
# 0   1  OLD  20112207                       미션임파서블:고스트프로토콜  2776060500
# 1   2  OLD  20110295                                마이 웨이  1189058500
# 2   3  OLD  20112621                        셜록홈즈 : 그림자 게임  1176022500
# 3   4  OLD  20113260                               퍼펙트 게임   644532000
# 4   5  OLD  20113271                        프렌즈: 몬스터섬의비밀    436753500
# 5   6  OLD  19940256                                라이온 킹   507115500
# 6   7  OLD  20113381                               오싹한 연애   344871000
# 7   8  OLD  20112709   극장판 포켓몬스터 베스트 위시「비크티니와 백의 영웅 레시라무」   167809500
# 8   9  OLD  20113311                            앨빈과 슈퍼밴드3   137030000
# 9  10  OLD  20112708  극장판 포켓몬스터 베스트 위시 「비크티니와 흑의 영웅 제크로무」   125535500
